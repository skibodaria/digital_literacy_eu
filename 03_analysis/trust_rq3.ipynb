# %% [markdown]
# # Institutional Trust & Disinformation
# Testing the actual relationship between a population's digital skills and their level of trust in institutions, as well as their resilience against disinformation
